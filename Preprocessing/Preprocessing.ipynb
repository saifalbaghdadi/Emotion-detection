# %%
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
import datetime
import os

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.layers import Dense, Input, Dropout,Flatten, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import save_model, load_model
from keras.callbacks import ModelCheckpoint, CSVLogger, TensorBoard, EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# ### Analyzing

# %%
# Importing Dataset

train_dir = '../data/train/'
test_dir = '../data/test/'

# %%
def plot_images(img_dir, top=10):
    all_img_dirs = os.listdir(img_dir)
    img_files = [os.path.join(img_dir, file) for file in all_img_dirs][:5]
    plt.figure(figsize=(10, 10))  
    for idx, img_path in enumerate(img_files):
        plt.subplot(5, 5, idx+1)
        img = plt.imread(img_path)
        plt.tight_layout()        
        plt.axis('off')
        plt.imshow(img, cmap='gray')

# %%
# ANGRY
plot_images(train_dir+'/angry')

# %%
# DISGUSTED
plot_images(train_dir+'/disgust')

# %%
# FEARFUL
plot_images(train_dir+'/fear')

# %%
# HAPPY
plot_images(train_dir+'/happy')

# %%
# NEUTRAL
plot_images(train_dir+'/neutral')

# %%
# SAD
plot_images(train_dir+'/sad')

# %%
# SURPRISED
plot_images(train_dir+'/surprise')

# %%
def plot_bar_chart_diagram(path_data):
  dic={}
  for emotion in  os.listdir(path_data):
    dem=0
    for x in os.listdir(path_data+"/"+emotion):
      dem+=1
    dic[emotion]=dem
  print(dic)
  barlist=plt.bar(range(len(dic)), list(dic.values()),tick_label=list(dic.keys()))
#set color
  plt.show()

# %%
plot_bar_chart_diagram(train_dir)
# Out:
# {'angry': 3980, 'disgust': 435, 'fear': 4091, 'happy': 7203, 'neutral': 4955, 'sad': 4826, 'surprise': 3163}

# %%
plot_bar_chart_diagram(test_dir)
# Out:
# {'angry': 953, 'disgust': 111, 'fear': 1019, 'happy': 1772, 'neutral': 1228, 'sad': 1246, 'surprise': 829}

# %% [markdown]
# ### Data Generator

# %%
# Create Training and Validation Batches by Using the ImageDataGenerator

img_size = 48
batch_size = 64

data_train = ImageDataGenerator(horizontal_flip=True)
train_generator = data_train.flow_from_directory(train_dir, target_size=(img_size,img_size), color_mode="grayscale",
                                                    batch_size=batch_size, class_mode='categorical', shuffle=True)

data_validation = ImageDataGenerator(horizontal_flip=True)
validation_generator = data_validation.flow_from_directory(test_dir, target_size=(img_size,img_size), color_mode="grayscale",
                                                    batch_size=batch_size, class_mode='categorical', shuffle=False)
# Out:
# Found 28653 images belonging to 7 classes.
# Found 7158 images belonging to 7 classes.

# %% [markdown]
# ### Create Convolutional Nueral Network (CNN) Model
# Create a Nueral Network using 4 Convolutional Layers and 2 Fully Connected dense Layers.

# %%
# Initialising the CNN
model = Sequential()

# %%
# 1st Convolution Layer

# There are 64 (3,3) filters with "same" Padding and Shape of the Input_Image is (48,48,1)
model.add(Conv2D(64,(3,3), padding='same', input_shape=(48, 48,1)))

# Normalizing to speed up learning.
model.add(BatchNormalization())

# Applying Non Linear Activation Function "relu"
model.add(Activation('relu'))  

# Adding a Max Pool Layer of size (2,2)
model.add(MaxPooling2D(pool_size=(2, 2)))

# Dropout layer with 0.25 fraction of the input units to drop
model.add(Dropout(0.25))

# %%
# 2nd Convolution layer

# There are 128 (5,5) filters with "same" Padding 
model.add(Conv2D(128,(5,5), padding='same'))

# Normalizing to speed up learning.
model.add(BatchNormalization())

# Applying Non Linear Activation Function "relu"
model.add(Activation('relu'))

# Adding a Max Pool Layer of size (2,2)
model.add(MaxPooling2D(pool_size=(2, 2)))

# Dropout layer with 0.25 fraction of the input units to drop
model.add(Dropout(0.25))

# %%
# 3rd Convolution layer

# There are 512 (3,3) filters with "same" Padding 
model.add(Conv2D(512,(3,3), padding='same'))

# Normalizing to speed up learning.
model.add(BatchNormalization())

# Applying Non Linear Activation Function "relu"
model.add(Activation('relu'))

# Adding a Max Pool Layer of size (2,2)
model.add(MaxPooling2D(pool_size=(2, 2)))

# Dropout layer with 0.25 fraction of the input units to drop
model.add(Dropout(0.25))

# %%
# 4th Convolution layer

# There are 512 (3,3) filters with "same" Padding 
model.add(Conv2D(512,(3,3), padding='same'))

# Normalizing to speed up learning.
model.add(BatchNormalization())

# Applying Non Linear Activation Function "relu"
model.add(Activation('relu'))

# Adding a Max Pool Layer of size (2,2)
model.add(MaxPooling2D(pool_size=(2, 2)))

# Dropout layer with 0.25 fraction of the input units to drop 
model.add(Dropout(0.25))

# %%
# Flattening
model.add(Flatten())

# Fully connected layer with 256 nuerons
model.add(Dense(256))

# Normalizing to speed up learning.
model.add(BatchNormalization())

# Applying Non Linear Activation Function "relu"
model.add(Activation('relu'))

# Dropout layer with 0.25 fraction of the input units to drop
model.add(Dropout(0.25))


# Fully connected layer with 512 nuerons
model.add(Dense(512))

# Normalizing to speed up learning.
model.add(BatchNormalization())

# Applying Non Linear Activation Function "relu"
model.add(Activation('relu'))

# Dropout layer with 0.25 fraction of the input units to drop
model.add(Dropout(0.25))

# Adding a final Dense Layer with 7 outputs corresponding to 7 different emotions with a "softmax" Activation Function 
model.add(Dense(7, activation='softmax'))

# %% [markdown]
# ### Compiling the Model
# I will use Adam Optimizer

# %%
# Adam is an optimization algorithm that can be used instead of the classical stochastic gradient descent 
# procedure to update network weights iterative based in training data.

# choose a Learning rate of 0.0005 
opt = Adam(learning_rate=0.0005)

# Compile defines the loss function, the optimizer and the metrics.

# As I have Categorical Values we will use 'categorical_crossentropy' loss function
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# check the details of the Model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 64)        640
#
#  batch_normalization (BatchN  (None, 48, 48, 64)       256
#  ormalization)
#
#  activation (Activation)     (None, 48, 48, 64)        0
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 64)       0
#  )
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 128)       204928
#
#  batch_normalization_1 (Batc  (None, 24, 24, 128)      512
#  hNormalization)
#
#  activation_1 (Activation)   (None, 24, 24, 128)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 512)       590336
#
#  batch_normalization_2 (Batc  (None, 12, 12, 512)      2048
#  hNormalization)
#
#  activation_2 (Activation)   (None, 12, 12, 512)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 512)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 512)         0
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 512)         2359808
#
#  batch_normalization_3 (Batc  (None, 6, 6, 512)        2048
#  hNormalization)
#
#  activation_3 (Activation)   (None, 6, 6, 512)         0
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 3, 512)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 3, 3, 512)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 256)               1179904
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 512)               131584
#
#  batch_normalization_5 (Batc  (None, 512)              2048
#  hNormalization)
#
#  activation_5 (Activation)   (None, 512)               0
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 4,478,727
# Trainable params: 4,474,759
# Non-trainable params: 3,968
# _________________________________________________________________

# %% [markdown]
# ### Train and Evaluate Model

# %%
# Because my computer is not powerful, I will use the training for 15 epochs and that takes (15+ minutes for each one epoch)

epochs = 15

steps_per_epoch = train_generator.n//train_generator.batch_size
validation_steps = validation_generator.n//validation_generator.batch_size

# Create a Callback which reduces the Learning rate by a factor of "0.1" when the val_loss does not decrease
# after 2 epochs also and allowing the minimum value of Learning Rate to be 0.00001
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                              patience=2, min_lr=0.00001, mode='auto')

# Create another Callback which saves the Model Weights by monitoring the Val_Accuracy
checkpoint = ModelCheckpoint("../model/model_weights_s1.h5", monitor='val_accuracy',
                             save_weights_only=True, mode='max', verbose=1)

# A callback is an object that can perform actions at various stages of training
callbacks = [checkpoint, reduce_lr]

# Fitting the model
history = model.fit( x=train_generator, steps_per_epoch=steps_per_epoch,
                     epochs=epochs, validation_data = validation_generator,
                     validation_steps = validation_steps, callbacks=callbacks)
# Out:
# Epoch 1/15
# 447/447 [==============================] - ETA: 0s - loss: 1.8124 - accuracy: 0.3040
# Epoch 1: saving model to ../model\model_weights_s1.h5
# 447/447 [==============================] - 1194s 3s/step - loss: 1.8124 - accuracy: 0.3040 - val_loss: 1.4975 - val_accuracy: 0.4258 - lr: 5.0000e-04
# Epoch 2/15
# 447/447 [==============================] - ETA: 0s - loss: 1.4901 - accuracy: 0.4304
# Epoch 2: saving model to ../model\model_weights_s1.h5
# 447/447 [==============================] - 1029s 2s/step - loss: 1.4901 - accuracy: 0.4304 - val_loss: 1.4014 - val_accuracy: 0.4495 - lr: 5.0000e-04
# Epoch 3/15
# 447/447 [==============================] - ETA: 0s - loss: 1.3332 - accuracy: 0.4882
# Epoch 3: saving model to ../model\model_weights_s1.h5
# 447/447 [==============================] - 958s 2s/step - loss: 1.3332 - accuracy: 0.4882 - val_loss: 1.3105 - val_accuracy: 0.4948 - lr: 5.0000e-04
# Epoch 4/15
# 447/447 [==============================] - ETA: 0s - loss: 1.2456 - accuracy: 0.5238
# Epoch 4: saving model to ../model\model_weights_s1.h5
# 447/447 [==============================] - 932s 2s/step - loss: 1.2456 - accuracy: 0.5238 - val_loss: 1.2491 - val_accuracy: 0.5182 - lr: 5.0000e-04
# Epoch 5/15
# 447/447 [==============================] - ETA: 0s - loss: 1.1940 - accuracy: 0.5434
# Epoch 5: saving model to ../model\model_weights_s1.h5
# 447/447 [==============================] - 899s 2s/step - loss: 1.1940 - accuracy: 0.5434 - val_loss: 1.2088 - val_accuracy: 0.5377 - lr: 5.0000e-04
# Epoch 6/15
# 447/447 [==============================] - ETA: 0s - loss: 1.1490 - accuracy: 0.5606
# Epoch 6: saving model to ../model\model_weights_s1.h5
# 447/447 [==============================] - 913s 2s/step - loss: 1.1490 - accuracy: 0.5606 - val_loss: 1.1440 - val_accuracy: 0.5598 - lr: 5.0000e-04
# Epoch 7/15
# 447/447 [==============================] - ETA: 0s - loss: 1.1151 - accuracy: 0.5747
# Epoch 7: saving model to ../model\model_weights_s1.h5
# 447/447 [==============================] - 890s 2s/step - loss: 1.1151 - accuracy: 0.5747 - val_loss: 1.0856 - val_accuracy: 0.5922 - lr: 5.0000e-04
# Epoch 8/15
# 447/447 [==============================] - ETA: 0s - loss: 1.0878 - accuracy: 0.5842
# Epoch 8: saving model to ../model\model_weights_s1.h5
# 447/447 [==============================] - 939s 2s/step - loss: 1.0878 - accuracy: 0.5842 - val_loss: 1.0848 - val_accuracy: 0.5883 - lr: 5.0000e-04
# Epoch 9/15
# 447/447 [==============================] - ETA: 0s - loss: 1.0655 - accuracy: 0.5973
# Epoch 9: saving model to ../model\model_weights_s1.h5
# 447/447 [==============================] - 926s 2s/step - loss: 1.0655 - accuracy: 0.5973 - val_loss: 1.1106 - val_accuracy: 0.5832 - lr: 5.0000e-04
# Epoch 10/15
# 447/447 [==============================] - ETA: 0s - loss: 1.0370 - accuracy: 0.6032
# Epoch 10: saving model to ../model\model_weights_s1.h5
# 447/447 [==============================] - 902s 2s/step - loss: 1.0370 - accuracy: 0.6032 - val_loss: 1.0814 - val_accuracy: 0.5897 - lr: 5.0000e-04
# Epoch 11/15
# 447/447 [==============================] - ETA: 0s - loss: 1.0170 - accuracy: 0.6145
# Epoch 11: saving model to ../model\model_weights_s1.h5
# 447/447 [==============================] - 1085s 2s/step - loss: 1.0170 - accuracy: 0.6145 - val_loss: 1.1609 - val_accuracy: 0.5656 - lr: 5.0000e-04
# Epoch 12/15
# 447/447 [==============================] - ETA: 0s - loss: 0.9920 - accuracy: 0.6279
# Epoch 12: saving model to ../model\model_weights_s1.h5
# 447/447 [==============================] - 1980s 4s/step - loss: 0.9920 - accuracy: 0.6279 - val_loss: 1.1253 - val_accuracy: 0.5781 - lr: 5.0000e-04
# Epoch 13/15
# 447/447 [==============================] - ETA: 0s - loss: 0.9197 - accuracy: 0.6546
# Epoch 13: saving model to ../model\model_weights_s1.h5
# 447/447 [==============================] - 1103s 2s/step - loss: 0.9197 - accuracy: 0.6546 - val_loss: 0.9782 - val_accuracy: 0.6330 - lr: 5.0000e-05
# Epoch 14/15
# 447/447 [==============================] - ETA: 0s - loss: 0.9012 - accuracy: 0.6588
# Epoch 14: saving model to ../model\model_weights_s1.h5
# 447/447 [==============================] - 1149s 3s/step - loss: 0.9012 - accuracy: 0.6588 - val_loss: 0.9685 - val_accuracy: 0.6388 - lr: 5.0000e-05
# Epoch 15/15
# 447/447 [==============================] - ETA: 0s - loss: 0.8888 - accuracy: 0.6654
# Epoch 15: saving model to ../model\model_weights_s1.h5
# 447/447 [==============================] - 1132s 3s/step - loss: 0.8888 - accuracy: 0.6654 - val_loss: 0.9669 - val_accuracy: 0.6443 - lr: 5.0000e-05

# %%
# Save Model
# save_model(model,'../model/model_1.h5')

# %%
# Evaluate Model
score = model.evaluate(validation_generator) 
print('Test loss: ', score[0])
print('Test accuracy: ', score[1])
# Out:
# 112/112 [==============================] - 53s 474ms/step - loss: 0.9605 - accuracy: 0.6459
# Test loss:  0.960469126701355
# Test accuracy:  0.6458507776260376

# %%
# Show Train History
keys=history.history.keys()
print(keys)

def show_train_history(hisData,train,test): 
    plt.plot(hisData.history[train])
    plt.plot(hisData.history[test])
    plt.title('Training History')
    plt.ylabel(train)
    plt.xlabel('Epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

show_train_history(history, 'loss', 'val_loss')
show_train_history(history, 'accuracy', 'val_accuracy')
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %% [markdown]
# ### Represent Model as JSON String

# %%
# Converting the model into JSON format and storing it in "model.json" file.
model_json = model.to_json()
with open("../model/model_json.json", "w") as json_file:
    json_file.write(model_json)
